# %%
import matplotlib.pyplot as plt
import seaborn as sns

x = ['Decision selection', 'Information analysis', 'Action implementation', 'Information acquisition']
y = [95,25,5,2]

ax=sns.barplot(y, x)
ax.set_xlabel('Count')
ax.set_ylabel('Category')
# Out:
# Text(0, 0.5, 'Category')

# %%
from matplotlib import pyplot
import seaborn
sns.set(font_scale=2)
a4_dims = (11.7, 8.27)
fig, ax = pyplot.subplots(figsize=a4_dims)
sns.barplot(ax=ax, y=x, x=y)
ax.set_xlabel('No. of Publications')
ax.set_ylabel('Category')
# Out:
# Text(0, 0.5, 'Category')
